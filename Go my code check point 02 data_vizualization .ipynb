# %%
import os 
import pandas as pd

df=pd.read_csv(r'C:\Users\montassar\titanic-passengers.csv',encoding='latin1',sep=';')

df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # CHECKING DATA¶
# check missing value

# %%
missing_values=df.columns[df.isnull().any()]
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
print(df['PassengerId'])
print(df['PassengerId'].isnull())
# Out:
# 0      343
# 1       76
# 2      641
# 3      568
# 4      672
#       ...
# 886     10
# 887     61
# 888    535
# 889    102
# 890    428
# Name: PassengerId, Length: 891, dtype: int64
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: PassengerId, Length: 891, dtype: bool

# %%
print(df['Survived'])
print(df['Survived'].isnull())
# Out:
# 0       No
# 1       No
# 2       No
# 3       No
# 4       No
#       ...
# 886    Yes
# 887     No
# 888     No
# 889     No
# 890    Yes
# Name: Survived, Length: 891, dtype: object
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Survived, Length: 891, dtype: bool

# %%
print(df['Pclass'])
print(df['Pclass'].isnull())
# Out:
# 0      2
# 1      3
# 2      3
# 3      3
# 4      1
#       ..
# 886    2
# 887    3
# 888    3
# 889    3
# 890    2
# Name: Pclass, Length: 891, dtype: int64
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Pclass, Length: 891, dtype: bool

# %%
print(df['Name'])
print(df['Name'].isnull())
# Out:
# 0                             Collander, Mr. Erik Gustaf
# 1                                Moen, Mr. Sigurd Hansen
# 2                                 Jensen, Mr. Hans Peder
# 3            Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4                                 Davidson, Mr. Thornton
#                              ...
# 886                  Nasser, Mrs. Nicholas (Adele Achem)
# 887                                Sirayanian, Mr. Orsen
# 888                                  Cacic, Miss. Marija
# 889                     Petroff, Mr. Pastcho ("Pentcho")
# 890    Phillips, Miss. Kate Florence ("Mrs Kate Louis...
# Name: Name, Length: 891, dtype: object
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Name, Length: 891, dtype: bool

# %%
print(df['Sex'])
print(df['Sex'].isnull())
# Out:
# 0        male
# 1        male
# 2        male
# 3      female
# 4        male
#         ...
# 886    female
# 887      male
# 888    female
# 889      male
# 890    female
# Name: Sex, Length: 891, dtype: object
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Sex, Length: 891, dtype: bool

# %%
print(df['Age'])
print(df['Age'].isnull())
# Out:
# 0      28.0
# 1      25.0
# 2      20.0
# 3      29.0
# 4      31.0
#        ...
# 886    14.0
# 887    22.0
# 888    30.0
# 889     NaN
# 890    19.0
# Name: Age, Length: 891, dtype: float64
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889     True
# 890    False
# Name: Age, Length: 891, dtype: bool

# %% [markdown]
# # Replacing missing numerical values¶

# %%
#age missing data 
df['Age'].fillna(df['Age'].mean(), inplace=True)
print()
#remove columns cabin
df.drop(columns='Cabin',inplace=True)

# %%
df.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0           343         0       2
# 1            76         0       3
# 2           641         0       3
# 3           568         0       3
# 4           672         0       1
# 5           105         0       3
# 6           576         0       3
# 7           382         1       3
# 8           228         0       3
# 9           433         1       2
# 10          135         0       2
# 11          294         0       3
# 12          755         1       2
# 13          595         0       2
# 14          127         0       3
# 15          434         0       3
# 16          378         0       1
# 17          533         0       3
# 18          666         0       2
# 19          225         1       1
#
#                                                  Name  Sex        Age  SibSp  \
# 0                          Collander, Mr. Erik Gustaf    1  28.000000      0
# ...

# %%
# we don"t have more information to replace the data missing in columns Cabin for that we remove this columns

# %% [markdown]
# # ViZUALISATION PART

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    object
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 83.7+ KB

# %%
import matplotlib.pyplot as plt   
     
df.Survived.value_counts().plot(kind="bar")

# %%
df.Survived.value_counts(normalize=True).plot(kind="bar")

# %%
import seaborn as sns
data_correlation = sns.FacetGrid(df, col="Sex", row="Survived", margin_titles=True)
data_correlation.map(plt.hist, "Age",color="GREEN");

# %% [markdown]
# # from graph above we conclude that :
# We can obviously see that approximate of 350 people survived and 550 people died, w. so 38% are survived and rest 0.62 are died
# we can understand that the older people died (between 50-70) and some of the younger people (between 20-40) survived more.

# %%
from sklearn.preprocessing import LabelEncoder 
encoder=LabelEncoder()
df["Survived"]=encoder.fit_transform(df["Survived"])
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0          343         0       2
# 1           76         0       3
# 2          641         0       3
# 3          568         0       3
# 4          672         0       1
# 5          105         0       3
# 6          576         0       3
# 7          382         1       3
# 8          228         0       3
# 9          433         1       2
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                         Collander, Mr. Erik Gustaf    1  28.0      0      0
# 1                            Moen, Mr. Sigurd Hansen    1  25.0      0      0
# 2                             Jensen, Mr. Hans Peder    1  20.0      0      0
# 3        Palsson, Mrs. Nils (Alma Cornelia Berglund)    0  29.0      0      4
# 4                             Davidson, Mr. Thornton    1  31.0      1      0
# 5                     Gustafsson, Mr. Anders Vilhelm    1  37.0      2      0
# ...

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0          343         0       2
# 1           76         0       3
# 2          641         0       3
# 3          568         0       3
# 4          672         0       1
# 5          105         0       3
# 6          576         0       3
# 7          382         1       3
# 8          228         0       3
# 9          433         1       2
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                         Collander, Mr. Erik Gustaf    1  28.0      0      0
# 1                            Moen, Mr. Sigurd Hansen    1  25.0      0      0
# 2                             Jensen, Mr. Hans Peder    1  20.0      0      0
# 3        Palsson, Mrs. Nils (Alma Cornelia Berglund)    0  29.0      0      4
# 4                             Davidson, Mr. Thornton    1  31.0      1      0
# 5                     Gustafsson, Mr. Anders Vilhelm    1  37.0      2      0
# ...

# %%
from sklearn.preprocessing import LabelEncoder 
encoder=LabelEncoder()
df["Sex"]=encoder.fit_transform(df["Sex"])

df.head(50)
# Out:
#     PassengerId  Survived  Pclass  \
# 0           343         0       2
# 1            76         0       3
# 2           641         0       3
# 3           568         0       3
# 4           672         0       1
# 5           105         0       3
# 6           576         0       3
# 7           382         1       3
# 8           228         0       3
# 9           433         1       2
# 10          135         0       2
# 11          294         0       3
# 12          755         1       2
# 13          595         0       2
# 14          127         0       3
# 15          434         0       3
# 16          378         0       1
# 17          533         0       3
# 18          666         0       2
# 19          225         1       1
# 20           83         1       3
# 21          130         0       3
# 22          544         1       2
# 23          815         0       3
# 24          273         1       2
# 25          464         0       2
# ...

# %%
corr=df.corr()
plt.figure(figsize=(10, 10))
sns.heatmap(corr, vmax=1, square=True,annot=True)
plt.title('Correlation ');

# %%
g = sns.FacetGrid(df, hue="Survived", col="Sex", margin_titles=True,
                palette="Set1",hue_kws=dict(marker=["^", "v"]))
g.map(plt.scatter, "Fare", "Age",edgecolor="w").add_legend()
plt.subplots_adjust(top=0.8)
g.fig.suptitle('Survival by Gender , Age and Fare')
# Out:
# Text(0.5, 0.98, 'Survival by Gender , Age and Fare')

# %%
df["Title"] = titles

rare_title = ['Dona', 'Lady', 'Countess','Capt', 'Col', 'Don', 
                'Dr', 'Major', 'Rev', 'Sir', 'Jonkheer']
df.loc[df["Title"] == "Mlle", "Title"] = 'Miss'
df.loc[df["Title"] == "Ms", "Title"] = 'Miss'
df.loc[df["Title"] == "Mme", "Title"] = 'Mrs'
df.loc[df["Title"] == "Dona", "Title"] = 'Royalty'
df.loc[df["Title"] == "Lady", "Title"] = 'Royalty'
df.loc[df["Title"] == "Countess", "Title"] = 'Royalty'
df.loc[df["Title"] == "Capt", "Title"] = 'Royalty'
df.loc[df["Title"] == "Col", "Title"] = 'Royalty'
df.loc[df["Title"] == "Don", "Title"] = 'Royalty'
df.loc[df["Title"] == "Major", "Title"] = 'Royalty'
df.loc[df["Title"] == "Rev", "Title"] = 'Royalty'
df.loc[df["Title"] == "Sir", "Title"] = 'Royalty'
df.loc[df["Title"] == "Jonkheer", "Title"] = 'Royalty'
df.loc[df["Title"] == "Dr", "Title"] = 'Royalty'

df["Title"].value_counts()

titles = df["Name"].apply(get_title)
print(pd.value_counts(titles))
# Out:
# Mr          517
# Miss        182
# Mrs         125
# Master       40
# Dr            7
# Rev           6
# Major         2
# Col           2
# Mlle          2
# Mme           1
# Don           1
# Countess      1
# Lady          1
# Capt          1
# Jonkheer      1
# Sir           1
# Ms            1
# Name: Name, dtype: int64

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass                                         Name  \
# 0          343         0       2                   Collander, Mr. Erik Gustaf
# 1           76         0       3                      Moen, Mr. Sigurd Hansen
# 2          641         0       3                       Jensen, Mr. Hans Peder
# 3          568         0       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672         0       1                       Davidson, Mr. Thornton
#
#    Sex   Age  SibSp  Parch      Ticket     Fare Embarked Title
# 0    1  28.0      0      0      248740  13.0000        S    Mr
# 1    1  25.0      0      0      348123   7.6500        S    Mr
# 2    1  20.0      0      0      350050   7.8542        S    Mr
# 3    0  29.0      0      4      349909  21.0750        S   Mrs
# 4    1  31.0      1      0  F.C. 12750  52.0000        S    Mr
