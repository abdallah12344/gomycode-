# %%
import os 
import pandas as pd

df=pd.read_csv(r'C:\Users\montassar\titanic-passengers.csv',encoding='latin1',sep=';')

df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# 886                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 887                              Sirayanian, Mr. Orsen    male  22.0      0
# 888                                Cacic, Miss. Marija  female  30.0      0
# 889                   Petroff, Mr. Pastcho ("Pentcho")    male   NaN      0
# 890  Phillips, Miss. Kate Florence ("Mrs Kate Louis...  female  19.0      0
#
#      Parch      Ticket     Fare  Cabin Embarked
# 0        0      248740  13.0000    NaN        S
# 1        0      348123   7.6500  F G73        S
# 2        0      350050   7.8542    NaN        S
# 3        4      349909  21.0750    NaN        S
# 4        0  F.C. 12750  52.0000    B71        S
# ..     ...         ...      ...    ...      ...
# 886      0      237736  30.0708    NaN        C
# 887      0        2669   7.2292    NaN        C
# 888      0      315084   8.6625    NaN        S
# 889      0      349215   7.8958    NaN        S
# 890      0      250655  26.0000    NaN        S
#
# [891 rows x 12 columns]

# %% [markdown]
# # CHECKING DATA¶
# check missing value

# %%
missing_values=df.columns[df.isnull().any()]
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
print(df['PassengerId'])
print(df['PassengerId'].isnull())
# Out:
# 0      343
# 1       76
# 2      641
# 3      568
# 4      672
#       ...
# 886     10
# 887     61
# 888    535
# 889    102
# 890    428
# Name: PassengerId, Length: 891, dtype: int64
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: PassengerId, Length: 891, dtype: bool

# %%
print(df['Survived'])
print(df['Survived'].isnull())
# Out:
# 0       No
# 1       No
# 2       No
# 3       No
# 4       No
#       ...
# 886    Yes
# 887     No
# 888     No
# 889     No
# 890    Yes
# Name: Survived, Length: 891, dtype: object
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Survived, Length: 891, dtype: bool

# %%
print(df['Pclass'])
print(df['Pclass'].isnull())
# Out:
# 0      2
# 1      3
# 2      3
# 3      3
# 4      1
#       ..
# 886    2
# 887    3
# 888    3
# 889    3
# 890    2
# Name: Pclass, Length: 891, dtype: int64
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Pclass, Length: 891, dtype: bool

# %%
print(df['Name'])
print(df['Name'].isnull())
# Out:
# 0                             Collander, Mr. Erik Gustaf
# 1                                Moen, Mr. Sigurd Hansen
# 2                                 Jensen, Mr. Hans Peder
# 3            Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4                                 Davidson, Mr. Thornton
#                              ...
# 886                  Nasser, Mrs. Nicholas (Adele Achem)
# 887                                Sirayanian, Mr. Orsen
# 888                                  Cacic, Miss. Marija
# 889                     Petroff, Mr. Pastcho ("Pentcho")
# 890    Phillips, Miss. Kate Florence ("Mrs Kate Louis...
# Name: Name, Length: 891, dtype: object
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Name, Length: 891, dtype: bool

# %%
print(df['Sex'])
print(df['Sex'].isnull())
# Out:
# 0        male
# 1        male
# 2        male
# 3      female
# 4        male
#         ...
# 886    female
# 887      male
# 888    female
# 889      male
# 890    female
# Name: Sex, Length: 891, dtype: object
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Sex, Length: 891, dtype: bool

# %%
print(df['Age'])
print(df['Age'].isnull())
# Out:
# 0      28.0
# 1      25.0
# 2      20.0
# 3      29.0
# 4      31.0
#        ...
# 886    14.0
# 887    22.0
# 888    30.0
# 889     NaN
# 890    19.0
# Name: Age, Length: 891, dtype: float64
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889     True
# 890    False
# Name: Age, Length: 891, dtype: bool

# %% [markdown]
# # Replacing missing numerical values¶

# %%
#age missing data 
df['Age'].fillna(df['Age'].mean(), inplace=True)
print()

# %%
df.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0           343         0       2
# 1            76         0       3
# 2           641         0       3
# 3           568         0       3
# 4           672         0       1
# 5           105         0       3
# 6           576         0       3
# 7           382         1       3
# 8           228         0       3
# 9           433         1       2
# 10          135         0       2
# 11          294         0       3
# 12          755         1       2
# 13          595         0       2
# 14          127         0       3
# 15          434         0       3
# 16          378         0       1
# 17          533         0       3
# 18          666         0       2
# 19          225         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 0                          Collander, Mr. Erik Gustaf    male  28.0      0
# 1                             Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                              Jensen, Mr. Hans Peder    male  20.0      0
# 3         Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                              Davidson, Mr. Thornton    male  31.0      1
# 5                      Gustafsson, Mr. Anders Vilhelm    male  37.0      2
# 6                                Patchett, Mr. George    male  19.0      0
# 7                         Nakid, Miss. Maria ("Mary")  female   1.0      0
# 8                     Lovell, Mr. John Hall ("Henry")    male  20.5      0
# 9   Louch, Mrs. Charles Alexander (Alice Adelaide ...  female  42.0      1
# 10                     Sobey, Mr. Samuel James Hayden    male  25.0      0
# 11                                Haas, Miss. Aloisia  female  24.0      0
# 12                   Herman, Mrs. Samuel (Jane Laver)  female  48.0      1
# 13                            Chapman, Mr. John Henry    male  37.0      1
# 14                                McMahon, Mr. Martin    male   NaN      0
# 15                         Kallio, Mr. Nikolai Erland    male  17.0      0
# 16                          Widener, Mr. Harry Elkins    male  27.0      0
# 17                               Elias, Mr. Joseph Jr    male  17.0      1
# 18                                 Hickman, Mr. Lewis    male  32.0      2
# 19                       Hoyt, Mr. Frederick Maxfield    male  38.0      1
#
#     Parch             Ticket      Fare  Cabin Embarked
# 0       0             248740   13.0000     G6        S
# 1       0             348123    7.6500  F G73        S
# 2       0             350050    7.8542     G6        S
# 3       4             349909   21.0750     G6        S
# 4       0         F.C. 12750   52.0000    B71        S
# 5       0            3101276    7.9250     G6        S
# 6       0             358585   14.5000     G6        S
# 7       2               2653   15.7417     G6        C
# 8       0          A/5 21173    7.2500     G6        S
# 9       0         SC/AH 3085   26.0000     G6        S
# 10      0         C.A. 29178   13.0000     G6        S
# 11      0             349236    8.8500     G6        S
# 12      2             220845   65.0000     G6        S
# 13      0        SC/AH 29037   26.0000     G6        S
# 14      0             370372    7.7500     G6        Q
# 15      0  STON/O 2. 3101274    7.1250     G6        S
# 16      2             113503  211.5000    C82        C
# 17      1               2690    7.2292     G6        C
# 18      0       S.O.C. 14879   73.5000     G6        S
# 19      0              19943   90.0000    C93        S

# %%
#remove columns cabin
df.drop(columns='Cabin')
# Out:
#      PassengerId  Survived  Pclass  \
# 0            343         0       2
# 1             76         0       3
# 2            641         0       3
# 3            568         0       3
# 4            672         0       1
# ..           ...       ...     ...
# 886           10         1       2
# 887           61         0       3
# 888          535         0       3
# 889          102         0       3
# 890          428         1       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# 886                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 887                              Sirayanian, Mr. Orsen    male  22.0      0
# 888                                Cacic, Miss. Marija  female  30.0      0
# 889                   Petroff, Mr. Pastcho ("Pentcho")    male   NaN      0
# 890  Phillips, Miss. Kate Florence ("Mrs Kate Louis...  female  19.0      0
#
#      Parch      Ticket     Fare Embarked
# 0        0      248740  13.0000        S
# 1        0      348123   7.6500        S
# 2        0      350050   7.8542        S
# 3        4      349909  21.0750        S
# 4        0  F.C. 12750  52.0000        S
# ..     ...         ...      ...      ...
# 886      0      237736  30.0708        C
# 887      0        2669   7.2292        C
# 888      0      315084   8.6625        S
# 889      0      349215   7.8958        S
# 890      0      250655  26.0000        S
#
# [891 rows x 11 columns]

# %%
# we don"t have more information to replace the data missing in columns Cabin for that we remove this columns

# %% [markdown]
# # ViZUALISATION PART

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    object
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        891 non-null    object
#  11  Embarked     891 non-null    object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 83.7+ KB

# %%
import matplotlib.pyplot as plt   
     
df.Survived.value_counts().plot(kind="bar")

# %%
df.Survived.value_counts(normalize=True).plot(kind="bar")

# %%
import seaborn as sns
data_correlation = sns.FacetGrid(df, col="Sex", row="Survived", margin_titles=True)
data_correlation.map(plt.hist, "Age",color="GREEN");

# %% [markdown]
# # from graph above we conclude that :
# We can obviously see that approximate of 350 people survived and 550 people died, w. so 38% are survived and rest 0.62 are died
# we can understand that the older people died (between 50-70) and some of the younger people (between 20-40) survived more.

# %%
from sklearn.preprocessing import LabelEncoder 
encoder=LabelEncoder()
df["Survived"]=encoder.fit_transform(df["Survived"])
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0          343         0       2
# 1           76         0       3
# 2          641         0       3
# 3          568         0       3
# 4          672         0       1
# 5          105         0       3
# 6          576         0       3
# 7          382         1       3
# 8          228         0       3
# 9          433         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                         Collander, Mr. Erik Gustaf    male  28.0      0
# 1                            Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                             Jensen, Mr. Hans Peder    male  20.0      0
# 3        Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                             Davidson, Mr. Thornton    male  31.0      1
# 5                     Gustafsson, Mr. Anders Vilhelm    male  37.0      2
# 6                               Patchett, Mr. George    male  19.0      0
# 7                        Nakid, Miss. Maria ("Mary")  female   1.0      0
# 8                    Lovell, Mr. John Hall ("Henry")    male  20.5      0
# 9  Louch, Mrs. Charles Alexander (Alice Adelaide ...  female  42.0      1
#
#    Parch      Ticket     Fare  Cabin Embarked
# 0      0      248740  13.0000    NaN        S
# 1      0      348123   7.6500  F G73        S
# 2      0      350050   7.8542    NaN        S
# 3      4      349909  21.0750    NaN        S
# 4      0  F.C. 12750  52.0000    B71        S
# 5      0     3101276   7.9250    NaN        S
# 6      0      358585  14.5000    NaN        S
# 7      2        2653  15.7417    NaN        C
# 8      0   A/5 21173   7.2500    NaN        S
# 9      0  SC/AH 3085  26.0000    NaN        S

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0          343         0       2
# 1           76         0       3
# 2          641         0       3
# 3          568         0       3
# 4          672         0       1
# 5          105         0       3
# 6          576         0       3
# 7          382         1       3
# 8          228         0       3
# 9          433         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                         Collander, Mr. Erik Gustaf    male  28.0      0
# 1                            Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                             Jensen, Mr. Hans Peder    male  20.0      0
# 3        Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                             Davidson, Mr. Thornton    male  31.0      1
# 5                     Gustafsson, Mr. Anders Vilhelm    male  37.0      2
# 6                               Patchett, Mr. George    male  19.0      0
# 7                        Nakid, Miss. Maria ("Mary")  female   1.0      0
# 8                    Lovell, Mr. John Hall ("Henry")    male  20.5      0
# 9  Louch, Mrs. Charles Alexander (Alice Adelaide ...  female  42.0      1
#
#    Parch      Ticket     Fare  Cabin Embarked
# 0      0      248740  13.0000     G6        S
# 1      0      348123   7.6500  F G73        S
# 2      0      350050   7.8542     G6        S
# 3      4      349909  21.0750     G6        S
# 4      0  F.C. 12750  52.0000    B71        S
# 5      0     3101276   7.9250     G6        S
# 6      0      358585  14.5000     G6        S
# 7      2        2653  15.7417     G6        C
# 8      0   A/5 21173   7.2500     G6        S
# 9      0  SC/AH 3085  26.0000     G6        S

# %%
from sklearn.preprocessing import LabelEncoder 
encoder=LabelEncoder()
df["Sex"]=encoder.fit_transform(df["Sex"])
df.head(50)
# Out:
#     PassengerId  Survived  Pclass  \
# 0           343         0       2
# 1            76         0       3
# 2           641         0       3
# 3           568         0       3
# 4           672         0       1
# 5           105         0       3
# 6           576         0       3
# 7           382         1       3
# 8           228         0       3
# 9           433         1       2
# 10          135         0       2
# 11          294         0       3
# 12          755         1       2
# 13          595         0       2
# 14          127         0       3
# 15          434         0       3
# 16          378         0       1
# 17          533         0       3
# 18          666         0       2
# 19          225         1       1
# 20           83         1       3
# 21          130         0       3
# 22          544         1       2
# 23          815         0       3
# 24          273         1       2
# 25          464         0       2
# 26          588         1       1
# 27          661         1       1
# 28           90         0       3
# 29          115         0       3
# 30          373         0       3
# 31          729         0       2
# 32          528         0       1
# 33          537         0       1
# 34          727         1       2
# 35           31         0       1
# 36          477         0       2
# 37          431         1       1
# 38          664         0       3
# 39           44         1       2
# 40          347         1       2
# 41          891         0       3
# 42          100         0       2
# 43           72         0       3
# 44          198         0       3
# 45          307         1       1
# 46          704         0       3
# 47           51         0       3
# 48          399         0       2
# 49          563         0       2
#
#                                                  Name  Sex   Age  SibSp  \
# 0                          Collander, Mr. Erik Gustaf    1  28.0      0
# 1                             Moen, Mr. Sigurd Hansen    1  25.0      0
# 2                              Jensen, Mr. Hans Peder    1  20.0      0
# 3         Palsson, Mrs. Nils (Alma Cornelia Berglund)    0  29.0      0
# 4                              Davidson, Mr. Thornton    1  31.0      1
# 5                      Gustafsson, Mr. Anders Vilhelm    1  37.0      2
# 6                                Patchett, Mr. George    1  19.0      0
# 7                         Nakid, Miss. Maria ("Mary")    0   1.0      0
# 8                     Lovell, Mr. John Hall ("Henry")    1  20.5      0
# 9   Louch, Mrs. Charles Alexander (Alice Adelaide ...    0  42.0      1
# 10                     Sobey, Mr. Samuel James Hayden    1  25.0      0
# 11                                Haas, Miss. Aloisia    0  24.0      0
# 12                   Herman, Mrs. Samuel (Jane Laver)    0  48.0      1
# 13                            Chapman, Mr. John Henry    1  37.0      1
# 14                                McMahon, Mr. Martin    1   NaN      0
# 15                         Kallio, Mr. Nikolai Erland    1  17.0      0
# 16                          Widener, Mr. Harry Elkins    1  27.0      0
# 17                               Elias, Mr. Joseph Jr    1  17.0      1
# 18                                 Hickman, Mr. Lewis    1  32.0      2
# 20      0             330932    7.7875     G6        Q        Miss
# 21      0             347061    6.9750     G6        S          Mr
# 22      0               2908   26.0000     G6        S          Mr
# 23      0             364499    8.0500     G6        S          Mr
# 24      1             250644   19.5000     G6        S         Mrs
# 25      0             234360   13.0000     G6        S          Mr
# 26      1              13567   79.2000    B41        C          Mr
# 27      0           PC 17611  133.6500     G6        S  Rare Title
# 28      0             343275    8.0500     G6        S          Mr
# 29      0               2627   14.4583     G6        C        Miss
# 30      0             323951    8.0500     G6        S          Mr
# 31      0             236853   26.0000     G6        S          Mr
# 32      0           PC 17483  221.7792    C95        S          Mr
# 33      0             113050   26.5500    B38        S  Rare Title
# 34      0              31027   21.0000     G6        S         Mrs
# 35      0           PC 17601   27.7208     G6        C  Rare Title
# 36      0              31027   21.0000     G6        S          Mr
# 37      0             110564   26.5500    C52        S          Mr
# 38      0             349210    7.4958     G6        S          Mr
# 39      2      SC/Paris 2123   41.5792     G6        C        Miss
# 40      0              31418   13.0000     G6        S        Miss
# 41      0             370376    7.7500     G6        Q          Mr
# 42      0             244367   26.0000     G6        S          Mr
# 43      2            CA 2144   46.9000     G6        S        Miss
# 44      1               4579    8.4042     G6        S          Mr
# 45      0              17421  110.8833     G6        C        Miss
# 46      0              36864    7.7417     G6        Q          Mr
# 47      1            3101295   39.6875     G6        S      Master
# 48      0             244278   10.5000     G6        S  Rare Title
# 49      0             218629   13.5000     G6        S          Mr

# %%
corr=df.corr()
plt.figure(figsize=(10, 10))
sns.heatmap(corr, vmax=1, square=True,annot=True)
plt.title('Correlation ');

# %%
g = sns.FacetGrid(df, hue="Survived", col="Sex", margin_titles=True,
                palette="Set1",hue_kws=dict(marker=["^", "v"]))
g.map(plt.scatter, "Fare", "Age",edgecolor="w").add_legend()
plt.subplots_adjust(top=0.8)
g.fig.suptitle('Survival by Gender , Age and Fare')
# Out:
# Text(0.5, 0.98, 'Survival by Gender , Age and Fare')

# %%
df.loc[df["Title"] == "Mlle", "Title"] = 'Miss'
df.loc[df["Title"] == "Ms", "Title"] = 'Miss'
df.loc[df["Title"] == "Mme", "Title"] = 'Mrs'
df.loc[df["Title"] == "Dona", "Title"] = 'Rare Title'
df.loc[df["Title"] == "Lady", "Title"] = 'Rare Title'
df.loc[df["Title"] == "Countess", "Title"] = 'Rare Title'
df.loc[df["Title"] == "Capt", "Title"] = 'Rare Title'
df.loc[df["Title"] == "Col", "Title"] = 'Rare Title'
df.loc[df["Title"] == "Don", "Title"] = 'Rare Title'
df.loc[df["Title"] == "Major", "Title"] = 'Rare Title'
df.loc[df["Title"] == "Rev", "Title"] = 'Rare Title'
df.loc[df["Title"] == "Sir", "Title"] = 'Rare Title'
df.loc[df["Title"] == "Jonkheer", "Title"] = 'Rare Title'
df.loc[df["Title"] == "Dr", "Title"] = 'Rare Title'

df["Title"].value_counts()

titles = df["Name"].apply(get_title)
print(pd.value_counts(titles))
# Out:
# Mr          517
# Miss        182
# Mrs         125
# Master       40
# Dr            7
# Rev           6
# Mlle          2
# Major         2
# Col           2
# Lady          1
# Countess      1
# Ms            1
# Capt          1
# Jonkheer      1
# Mme           1
# Don           1
# Sir           1
# Name: Name, dtype: int64

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass                                         Name  \
# 0          343         0       2                   Collander, Mr. Erik Gustaf
# 1           76         0       3                      Moen, Mr. Sigurd Hansen
# 2          641         0       3                       Jensen, Mr. Hans Peder
# 3          568         0       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672         0       1                       Davidson, Mr. Thornton
#
#    Sex   Age  SibSp  Parch      Ticket     Fare  Cabin Embarked Title
# 0    1  28.0      0      0      248740  13.0000     G6        S    Mr
# 1    1  25.0      0      0      348123   7.6500  F G73        S    Mr
# 2    1  20.0      0      0      350050   7.8542     G6        S    Mr
# 3    0  29.0      0      4      349909  21.0750     G6        S   Mrs
# 4    1  31.0      1      0  F.C. 12750  52.0000    B71        S    Mr
