# %% [markdown]
# <div style="text-align:left"><span style="color:#448a97; font-family:Georgia; font-size:1.5em;"> Ben Abdallah Walid </span></div>
#
# ************************************************************************
#
# <div style="text-align:center"><span style="color: #FF9900; font-family:Georgia; font-size:2em;"> PROJECT:Preduction Model of Wine Quality </span></div>

# %% [markdown]
# # Table of contents
# 1. [<div style="font-family: italic; font-size:1.6em;color:indigo;">Introduction</span></div>](#introduction)
# 2. [<div style="font-family: italic; font-size:1.6em;color:black;">Main Purpose</span></div>](#paragraph1)
#     1. [<div style="font-family: COMIC; font-size:1.3em;color:navy;">Aim of project</span></div>](#subparagraph1)
#     1. [<div style="font-family: COMIC; font-size:1.3em;color:navy;">General physicochemicals proprieties of wine: Brief description</span></div>](#subparagraph1)
# 3. [<div style="font-family: italic; font-size:1.6em;color:black;">Data Preprocessing</span></div>](#paragraph2)
# 4. [<div style="font-family: italic; font-size:1.6em;color:black;">Data Visualization and Analyses</span></div>](#paragraph3)
#
# 5. [<div style="font-family: italic; font-size:1.6em;color:black;">Machine learning and Prediction Algorithms</span></div>](#paragraph4)
#     1. [<div style="font-family: COMIC; font-size:1.3em;color:navy;">Quality Prediction Red Wine </span></div>](#subparagraph4)
#      1. [<div style="font-family: COMIC; font-size:1.3em;color:green;">Logistic Regression </span></div>](#subparagraph4)
#      1. [<div style="font-family: COMIC; font-size:1.3em;color:green;">Decision Tree </span></div>](#subparagraph4)
#      1. [<div style="font-family: COMIC; font-size:1.3em;color:green;">Random Forest </span></div>](#subparagraph4)
#      1. [<div style="font-family: COMIC; font-size:1.3em;color:green;">KNN </span></div>](#subparagraph4)
#     1. [<div style="font-family: COMIC; font-size:1.3em;color:navy;">Quality Prediction white Wine </span></div>](#subparagraph4)
#      1. [<div style="font-family: COMIC; font-size:1.3em;color:green;">Logistic Regression </span></div>](#subparagraph4)
#      1. [<div style="font-family: COMIC; font-size:1.3em;color:green;">Decision Tree </span></div>](#subparagraph4)
#      1. [<div style="font-family: COMIC; font-size:1.3em;color:green;">Random Forest </span></div>](#subparagraph4)
#      1. [<div style="font-family: COMIC; font-size:1.3em;color:green;">KNN </span></div>](#subparagraph4)
# <div style="font-family: Arial; font-size:1.3em;color:blue;"> </span></div>
# 6. [<div style="font-family: italic; font-size:1.6em;color:black;">Select the best Method</div>](#paragraph4)
#      1. [<div style="font-family: COMIC; font-size:1.3em;color:navy;">For Red Wine </span></div>](#subparagraph4)
#      1. [<div style="font-family: COMIC; font-size:1.3em;color:navy;">FOr white Wine </span></div>](#subparagraph4)
# 7. [<div style="font-family: italic; font-size:1.6em;color:black;">Conclusion</div>](#paragraph4)

# %% [markdown]
# 1. [<div style="font-family: italic; font-size:1.6em;color:indigo;">Introduction</span></div>](#introduction)
# **************************************************************************************
#  Wine industry is  researching new  technologies for both wine  making and selling processes in order to back up this growth . Physicochemical and sensory  tests are used  for evaluating  wine certification  .  The  discrimination  of  wines  is  not  an  easy process  owing  to  the  complexity  and  heterogeneity  of  its headspace. The classification of wines is very important because of different  reasons. __These  reasons are economic value  of wine products,  to  protect and  assure  the  quality  of  wines, to  forbid adulteration of wines, and to control beverage processing__
#  ****************************************************************************************
# 2. [<div style="font-family: italic; font-size:1.6em;color:indigo;">Main Purpose</span></div>](#paragraph1)
#
#     2. [<div style="font-family: COMIC; font-size:1.3em;color:blue;">Aim of project</span></div>](#subparagraph1)
#  ************************************************
#
# Setup THE DMAIC Method(Define-Measure-Analyse-Improve and Control) and the algorithmique machine learning in order to:
#  * __improve efficiency from Farmer to consumer__
#  * __improve yield and Quality product during all stage starting by Farmer__
# *******************************
#    <div style="font-family: COMIC; font-size:1.3em;color:blue;">C.General physicochemicals proprieties of wine: Brief description</span></div>
#
# *************************************
# * <strong><em> Residual Sugar </em></strong>: Residual sugar represents the amount of sugar remaining after alcoholic fermentation, when yeasts have converted grape sugars into alcohol. The higher the level of residual sugar, the sweeter the wine and the fuller or more viscous it can taste in the mouth.
# Managing sugar levels include:
# lowering the temperature  to stop fermentation when the wine reaches the desired sweetness.
# adding sulfur dioxide to stop fermentation.
# adding neutral grape alcohol to stop fermentation, such as in fortified wines like Port.
# adding unfermented grape must (the juice before fermentation) to the fermented wine to increase the amount of sugar.
#
# * __Volatile Acidity__: In general "The maximum volatile acidity, calculated as acetic acid and exclusive of sulfur dioxide, is 0.14 g/100 mL for red wine and 0.12 g/100 mL for white wines." This is equivalent to 1.4 and 1.2 g/L acetic acid for red and white wines, respectively
#
# * __Fixed acidity__ : most acid involved with wine or fixed or nonvolatile(do not evaporate readily)
#
# * __Citric acid__: found in small quantities, citric acid can add 'freshness'and flavors to wine
#
# * __clhorides__: amount of salt in the wine
#
# * __free_sulfure dioxyde__: the free from so2 exists in equilibrium betwen molecular SO2 and bisulfite ion : it prevent microbial growth and the oxidation of wine
#
# * __total_sulfure_dioxyde__: amount of free and bounds form of SO2 , in low concentration SO2 is mostly indetectable in wine, 2-but at free SO2 concentration over 50 ppm SO2 becomes evident in the taste of wine
#
# * __density__ : wine density
#
# * __PH__ : describes how acidic or basic a wine is on a scale 0(very acidic) to 14 14(very basic) most wine are PH betwen 3 and 4
#
# * __SULPHATES__: a wine additive which can contribute to sulfur dioxyd gas (SO2)levels which act as antimicrobial and antioxydant
#
# * __Alcahol__: the percent alcahol contient of the wine
#
# * __Quality__: output variable based on sensory data and scaled betwen 0 to 10

# %% [markdown]
# 3. [Data Preprocessing](#paragraph2)
# ************************************
# we load two dataset for two type of  wine characteristics red and white and prédict the quality in the next step .the data set contains  :
#
# * <strong><em>4898  rows*12 columns sampling the chemical composition of white wine</em></strong>
#
# * <strong><em>1599 rows*12 columns sampling the chemical composition of red  wine</em></strong>
#
# and check the missing and type of value in order to find data that is not suitable for direct processing by machine learning algorithms, and proceed to cleaning and transformation if exixt .

# %%
import os 
import pandas as pd

v_blanc=pd.read_csv(r'C:\Users\montassar\Desktop\vin_blanc.csv',sep=';')

v_blanc
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
import os 
import pandas as pd

v_rouge=pd.read_csv(r'C:\Users\montassar\Desktop\vin_rouge.csv',sep=';')

v_rouge
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
import pandas as pd
import statsmodels.formula.api as smf
import statsmodels.stats.multicomp as multi
import scipy.stats
import numpy as np
import seaborn
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
v_blanc.info()
v_rouge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# ...

# %% [markdown]
# 4. [<div style="font-family: italic; font-size:1.6em;color:#003399;">Data Visualization and Analyses</span></div>](#paragraph3)

# %%
v_rouge.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %% [markdown]
# <p style="font-family: comic; font-size:1.4em;color:blue;">Quicks Remarks for same Parameter </p>
#
#
# | Parameter| Remarks|Interpretation|
# | :--- | :--- |:--- |
# | __`Alcahool`__ | same red wine very weak (alcahool in RED wine<10)_| alcohol, commonly referred to as Ethanol,is the major compound produced by Saccharomyces cerevisiae yeasts from C6 sugars during alcoholic fermentation.Glycolysis followed by decarboxylation of pyruvic acid and reduction of ethanal results in its production.So we conclude from this parameter that thes causes possibles are : Fermentation process (temperature control of fermentation for example), sugar contains in initial fruits ,  ethanal much higher and we need to reduce it and probable problem in bottling process|
#     | __`chlorides`__ |chlorides : same wine are salty (chlorides>0.6)|standard deviation 0.04,max=0.6,min=0.012 considered as high deviation .note that Chloride concentration in the wine is influenced by terroir and its highest  where irrigation is carried out using salty water or in areas with brackish terrains . this is economical issue due to the grap type and origin that the importance of quantification lies in the fact that wine flavor is strongly impacted by this particular ion, which, in high concentration, gives the wine an undesirable salty taste and significantly decreases its market |
# | __`residual sugar`__ | the fermentation is not over for same wine |the residaual sugar  refers to the sugars left unfermented in a finished winethe standard deviation (1.40) with a mean 2.53 considered a high deviation, |
# |__Acidity,PH__ |same wine are much more acid than the other |the pH depend by the acidity(fixed,volatile or citric) and looking for the parameter we conclude the deviation is important. the classification of the acid can give us a good understood how the acid can affect the quality of wine . we can consider  as two type organic acid isue from nature and the quality of graps such as citric acid and fixed acid and the acid organic result from the fermentation process such as Volatile acid . this two components have a big impact in quality of wine|

# %%
v_blanc.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %% [markdown]
# <p style="font-family: comic; font-size:1.4em;color:blue;">Quicks Remarks for same Parameter </p>
#
#
# | Parameter| Remarks|Interpretation|
# | :--- | :--- |:--- |
# | __`Alcahool`__ | same red wine very weak (alcahool in RED wine<10)_| Ethanol, commonly referred to as alcohol,is the major compound produced by Saccharomyces cerevisiae yeasts from C6 sugars during alcoholic fermentation.Glycolysis followed by decarboxylation of pyruvic acid and reduction of ethanal results in its production.So we conclude from this parameter that thes causes possibles are : Fermentation process (temperature control of fermentation for example), sugar contains in initial fruits ,  ethanal much higher and we need to reduce it and probable problem in bottling process|
#     | __`Chlorides`__ |chlorides : same wine are salty (chlorides>0.6)|standard deviation 0.04,max=0.6,min=0.012 considered as high deviation .note that Chloride concentration in the wine is influenced by terroir and its highest  where irrigation is carried out using salty water or in areas with brackish terrains . this is economical issue due to the grap type and origin that the importance of quantification lies in the fact that wine flavor is strongly impacted by this particular ion, which, in high concentration, gives the wine an undesirable salty taste and significantly decreases its market |
# | __`Residual sugar`__ | the fermentation is not over for same wine |the residaual sugar  refers to the sugars left unfermented in a finished winethe standard deviation (1.40) with a mean 2.53 considered a high deviation, |
# |__Acidity,PH__ |same wine are much more acid than the other |the pH depend by the acidity(fixed,volatile or citric) and looking for the parameter we conclude the deviation is important. the classification of the acid can give us a good understood how the acid can affect the quality of wine . we can consider  as two type organic acid isue from nature and the quality of graps such as citric acid and fixed acid and the acid organic result from the fermentation process such as Volatile acid . this two components have a big impact in quality of wine|

# %%
# HISTOGRAMS RED WINE 
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import norm 

graph_by_variables = ['fixed acidity', 'volatile acidity', 'citric acid',
       'residual sugar','alcohol', 'chlorides', 'free sulfur dioxide',
       'total sulfur dioxide', 'density',
       'pH', 'sulphates','quality']
plt.figure(figsize=(15,18))
for i in range(0,12):
    plt.subplot(6,3,i+1)
    sns.distplot(v_rouge[graph_by_variables[i]].dropna(),fit=norm)
    plt.title(graph_by_variables[i])


plt.tight_layout()

# %%
# HISTOGRAME FOR WHITE WINE 
graph_by_variables = ['fixed acidity', 'volatile acidity', 'citric acid',
       'residual sugar','alcohol', 'chlorides', 'free sulfur dioxide',
       'total sulfur dioxide', 'density',
       'pH', 'sulphates','quality']
plt.figure(figsize=(15,18))

for i in range(0,12):
    plt.subplot(6,3,i+1)
    sns.distplot(v_blanc[graph_by_variables[i]].dropna(),fit=norm)
    plt.title(graph_by_variables[i])

plt.tight_layout()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
def correlation_heatmap(v_rouge):
    _,ax=plt.subplots(figsize=(15,10))
    colormap=sns.diverging_palette(220,10,as_cmap=True)
    sns.heatmap(v_rouge.corr(),annot=True,cmap=colormap)
    
correlation_heatmap(v_rouge)

# %% [markdown]
#
#  <span style='background :Yellow' > In red wine the quality is very correlated with alcahool, sulphates and differents types of acid (volatile, fixed and citric acid) </span>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
def correlation_heatmap(v_blanc):
    _,ax=plt.subplots(figsize=(15,10))
    colormap=sns.diverging_palette(220,10,as_cmap=True)
    sns.heatmap(v_blanc.corr(),annot=True,cmap=colormap)
    
correlation_heatmap(v_blanc)

# %% [markdown]
#  <span style='background :Yellow' > In white wine the quality is very correlated with alcahool, density and clhorides and less in differents types of acid (volatile, fixed and citric acid) </span>

# %%
plt.figure(figsize=(20,35))

for i in range(0,12):
    plt.subplot(6, 3, i+1)
    plt.boxplot(v_blanc[graph_by_variables[i]].dropna())
    plt.title(graph_by_variables[i])

# %%
plt.figure(figsize=(20,35))

for i in range(0,12):
    plt.subplot(6, 3, i+1)
    plt.boxplot(v_rouge[graph_by_variables[i]].dropna())
    plt.title(graph_by_variables[i])

# %%
# check process Variabilty and Test of Normality 
import scipy.stats as stats
d=v_blanc[['alcohol']].hist(figsize=(10,8))
plt.tight_layout()

print(d)
# Out:
# [[<matplotlib.axes._subplots.AxesSubplot object at 0x00000272CD41C3A0>]]

# %%
#chek skewness 
print(stats.skew(v_blanc[['alcohol']]))
# Out:
# [0.48719273]

# %%
# Test shapiro 
w, p=stats.shapiro(v_blanc[['alcohol']])
print((w, p))
# Out:
# (0.955296516418457, 2.5578040326544056e-36)

# %%
#test Kolmogrov smirnov 
D,p=stats.kstest((v_blanc[['alcohol']]),'norm')
print('kolmogrov-smirnov: D:(0) p=(1)',(D,p))
# Out:
# kolmogrov-smirnov: D:(0) p=(1) (1.0, 0.0)

# %%
# Test Anderson Darling 
import plotly.graph_objs as go
import plotly.figure_factory as ff

import numpy as np
import pandas as pd
import scipy
import chart_studio
import chart_studio.plotly as py
import plotly.graph_objects as go
from scipy.stats import anderson
from plotly.offline import plot

result = anderson(v_blanc['alcohol'])
stat = round(result.statistic, 4)

p = 0
result_mat = []
for i in range(len(result.critical_values)):
    sl, cv = result.significance_level[i], result.critical_values[i]
    if result.statistic < result.critical_values[i]:
        msg = 'Sample looks Gaussian (fail to reject H0)'
    else:
        msg = 'Sample does not look Gaussian (reject H0)'
    result_mat.append([len(v_blanc[['alcohol']]), stat, sl, cv, msg])

trace = go.Table(
    header=dict(values=['<b>Sample Size</b>', '<b>Statistic</b>', '<b>Significance Level</b>', '<b>Critical Value</b>', '<b>Comment</b>'],
                line = dict(width=0),
                fill = dict(color='rgba(42,63,95,0.8)'),
                align = 'center',
                font = dict(
                    color = '#ffffff',
                    size = 12
                )),
    cells=dict(values=np.array(result_mat).T,
               line = dict(width=0),
               fill = dict(color=[['#EBF0F8', '#ffffff', '#EBF0F8', '#ffffff', '#EBF0F8']]),
               align = 'center',
               height = 40),
    columnwidth=[0.3, 0.25, 0.3, 0.25, 0.5])
layout = dict(
    height=300,
    margin=dict(
        l=5,
        r=5,
        t=30,
        b=0
    )
)
data = [trace]
andar_table = dict(data=data, layout=layout)

plot(andar_table, filename='anderson-darling-table')
# Out:
# 'anderson-darling-table.html'

# %%
from IPython.display import Image
from IPython.core.display import HTML 
Image(r"C:\Users\montassar\Desktop\Capture 02.PNG")

# %%
from __future__ import division, unicode_literals 
import codecs
from bs4 import BeautifulSoup

f=codecs.open(r"C:\Users\montassar\Desktop\anderson-darling-table.html",encoding='utf-8')
document= BeautifulSoup(f.read()).get_text()
print (document)
# Out:
#
#  64.761864.761864.761864.761864.7618Statistic15.010.05.02.51.0Significance Level0.5760.6550.7860.9171.091Critical ValueSample does not look Gaussian (reject H0)Sample does not look Gaussian (reject H0)Sample does not look Gaussian (reject H0)Sample does not look Gaussian (reject H0)Sample does not look Gaussian (reject H0)Comment48984898489848984898Sample Sizeplotly-logomark

# %%
# Histogramme chlorides 
import scipy.stats as stats
f=v_blanc[['chlorides']].hist(figsize=(10,8))
plt.tight_layout()

print(f)
# Out:
# [[<matplotlib.axes._subplots.AxesSubplot object at 0x00000272CA1E4520>]]

# %%
#Skewness 
print('skewness',stats.skew(v_blanc[['alcohol']]))
#test Kolmogrov smirnov 
D,p=stats.kstest((v_blanc[['chlorides']]),'norm')
print('kolmogrov-smirnov: D:(0) p=(1)',(D,p))
#test shapiro 
w, p=stats.shapiro(v_blanc[['chlorides']])
print('test shapiro', (w, p))
# Out:
# skewness [0.48719273]
# kolmogrov-smirnov: D:(0) p=(1) (0.6353286426312534, 0.0)
# test shapiro (0.5908077955245972, 0.0)

# %%
import plotly.graph_objs as go
import plotly.figure_factory as ff

import numpy as np
import pandas as pd
import scipy
import chart_studio
import chart_studio.plotly as py
import plotly.graph_objects as go
from scipy.stats import anderson
from plotly.offline import plot

result = anderson(v_blanc['chlorides'])
stat = round(result.statistic, 4)

p = 0
result_mat = []
for i in range(len(result.critical_values)):
    sl, cv = result.significance_level[i], result.critical_values[i]
    if result.statistic < result.critical_values[i]:
        msg = 'Sample looks Gaussian (fail to reject H0)'
    else:
        msg = 'Sample does not look Gaussian (reject H0)'
    result_mat.append([len(v_blanc[['chlorides']]), stat, sl, cv, msg])

trace = go.Table(
    header=dict(values=['<b>Sample Size</b>', '<b>Statistic</b>', '<b>Significance Level</b>', '<b>Critical Value</b>', '<b>Comment</b>'],
                line = dict(width=0),
                fill = dict(color='rgba(42,63,95,0.8)'),
                align = 'center',
                font = dict(
                    color = '#ffffff',
                    size = 12
                )),
    cells=dict(values=np.array(result_mat).T,
               line = dict(width=0),
               fill = dict(color=[['#EBF0F8', '#ffffff', '#EBF0F8', '#ffffff', '#EBF0F8']]),
               align = 'center',
               height = 40),
    columnwidth=[0.3, 0.25, 0.3, 0.25, 0.5])
layout = dict(
    height=300,
    margin=dict(
        l=5,
        r=5,
        t=30,
        b=0
    )
)
data = [trace]
andar_table = dict(data=data, layout=layout)

plot(andar_table, filename='anderson-darling-table')
# Out:
# 'anderson-darling-table.html'

# %%
from IPython.display import Image
from IPython.core.display import HTML 
Image(r"C:\Users\montassar\Desktop\darling chlorides.PNG")

# %% [markdown]
#  <span style='background :Yellow' > ==>According the 3 test Anderson Darling, Shapiro and Kolmogrov smirnov we conclud that the sample of Alcahol, Clhoride in white wine not look a Gaussian </span>

# %%
import scipy.stats as stats
e=v_rouge[['quality']].hist(figsize=(10,8))
plt.tight_layout()
e2=v_rouge[['volatile acidity']].hist(figsize=(10,8))
plt.tight_layout()
e3=e2=v_rouge[['alcohol']].hist(figsize=(10,8))
plt.tight_layout()
print(e)
print(e2)
print(e3)
# Out:
# [[<matplotlib.axes._subplots.AxesSubplot object at 0x00000272CA23C430>]]
# [[<matplotlib.axes._subplots.AxesSubplot object at 0x00000272CE7FE6D0>]]
# [[<matplotlib.axes._subplots.AxesSubplot object at 0x00000272CE7FE6D0>]]

# %%
#Test Normality for Red Wine by different Method 

print('skewness quality ',stats.skew(v_rouge[['quality']]))
print('skewness volatile acidity',stats.skew(v_rouge[['volatile acidity']]))
print('skewness alcohol',stats.skew(v_rouge[['alcohol']]))

w, p=stats.shapiro(v_rouge[['quality']])
print('shapiro Test quality', (w, p))

w, p=stats.shapiro(v_rouge[['volatile acidity']])
print('shapiro Test volatile acidity ', (w, p))
w, p=stats.shapiro(v_rouge[['alcohol']])
print('shapiro Test alcohol', (w, p))

D,p=stats.kstest((v_rouge[['quality']]),'norm')
print('kolmogrov-smirnov: D:(0) p=(1)',(D,p))
D,p=stats.kstest((v_rouge[['volatile acidity']]),'norm')
print('kolmogrov-smirnov volatile acidity: D:(0) p=(1)',(D,p))
D,p=stats.kstest((v_rouge[['alcohol']]),'norm')
print('kolmogrov-smirnov alcohol: D:(0) p=(1)',(D,p))

# SEEMS According the test all the samples are not Gaussian
# Out:
# skewness quality  [0.21759721]
# skewness volatile acidity [0.6709624]
# skewness alcohol [0.86002106]
# shapiro Test quality (0.8575843572616577, 9.504003839923922e-36)
# shapiro Test volatile acidity  (0.9743340611457825, 2.686806772838566e-16)
# shapiro Test alcohol (0.9288389682769775, 6.643664824998876e-27)
# kolmogrov-smirnov: D:(0) p=(1) (0.9999999999999993, 0.0)
# kolmogrov-smirnov volatile acidity: D:(0) p=(1) (0.9429465667622459, 0.0)
# kolmogrov-smirnov alcohol: D:(0) p=(1) (1.0, 0.0)

# %%
# Test Normality BY Anderson Darling 

import plotly.graph_objs as go
import plotly.figure_factory as ff

import numpy as np
import pandas as pd
import scipy
import chart_studio
import chart_studio.plotly as py
import plotly.graph_objects as go
from scipy.stats import anderson
from plotly.offline import plot


stat = round(result.statistic, 4)

p = 0
result_mat = []
for i in range(len(result.critical_values)):
    sl, cv = result.significance_level[i], result.critical_values[i]
    if result.statistic < result.critical_values[i]:
        msg = 'Sample looks Gaussian (fail to reject H0)'
    else:
        msg = 'Sample does not look Gaussian (reject H0)'
    result_mat.append([len(v_rouge[['quality']]), stat, sl, cv, msg])

trace = go.Table(
    header=dict(values=['<b>Sample Size</b>', '<b>Statistic</b>', '<b>Significance Level</b>', '<b>Critical Value</b>', '<b>Comment</b>'],
                line = dict(width=0),
                fill = dict(color='rgba(42,63,95,0.8)'),
                align = 'center',
                font = dict(
                    color = '#ffffff',
                    size = 12
                )),
    cells=dict(values=np.array(result_mat).T,
               line = dict(width=0),
               fill = dict(color=[['#EBF0F8', '#ffffff', '#EBF0F8', '#ffffff', '#EBF0F8']]),
               align = 'center',
               height = 40),
    columnwidth=[0.3, 0.25, 0.3, 0.25, 0.5])
layout = dict(
    height=300,
    margin=dict(
        l=5,
        r=5,
        t=30,
        b=0
    )
)
data = [trace]
andar_table = dict(data=data, layout=layout)

plot(andar_table, filename='anderson-darling-table')
# Out:
# 'anderson-darling-table.html'

# %%
from IPython.display import Image
from IPython.core.display import HTML 
Image(r"C:\Users\montassar\Desktop\darling 02.PNG")

# %% [markdown]
# | wine type| parameter|Skewness|Test shapiro |kolmogrov-smirnov|Darling|
# | :--- | :--- |:--- |:--- |:--- |:--- |
# | __`red wine `__ |quality|0.21759721|(w, p)(0.85758435, 9.50400e-36)| D:(0) p=(1) (0.99999, 0.0)|critical value value(0.576,0.655,0.786,0.917,1.091)-signif level( 15,10,5,2.5,1)|
#     | __`red wine`__ |volatile acidity |0.6709624 |(w, p)(0.9743345, 2.6868067726e-16)| D:(0) p=(1) 0.9429465667622459, 0.0|   |
# | __`red wine`__ | alcohol |0.86002106|(w, p)(0.8575843572, 9.50400383992e-36)| D:(0) p=(1) 0.9999999999999993, 0.0|
# |__'white wine'__|alcohol | 0.48719273|w, p)(0.955296516418457, 2.5578040326544056e-36)|D:(0) p=(1) (1.0, 0.0)|        |
#
#
# <span style='background :Yellow' > ==>According the 3 test Anderson Darling, Shapiro and Kolmogrov smirnov we conclud that the FINAL Quality of red wine  not look a Gaussian </span>
# *****************************
# <p style="font-family: comic; font-size:1.4em;color:blue;">Conclusion :the process is NOT stable SO the difficulty in prevision and this do in differents parameters such as quality product graps (origine,storage,harvesting technique,transport,irrigation,climat,nitrogen fixation in sol ) and Process capability especially the process of pressing,fermentation and bottling</p>
#
#
# ********************************
# <p style="font-family: comic; font-size:1.4em;color:blue;">The next step will divise the quality into three category (low, medium and high) and analyze relationship between a set of independent and dependent variables </p>

# %%
def call_red(functionToCall):
    print('\nRed Wine\n')
    functionToCall(v_rouge)
def call_white(functionToCall):
    print('\nWhite Wine\n')
    functionToCall(v_blanc)
    
def rm1(red1_set):
    red1_set.columns = [x.strip() for x in red1_set.columns]
call_red(rm1)

def rm2(white_set):
    white_set.columns = [x.strip() for x in white_set.columns]
call_white(rm2)
# Out:
# Red Wine
#
#
# White Wine

# %%
# Add a column 'quality_mark' for V_red 
def add_categ_quality(red1_set):
    low = red1_set[red1_set['quality'] <= 5]
    medium = red1_set[(red1_set['quality'] == 6) | (red1_set['quality'] == 7)]
    high = red1_set[red1_set['quality'] > 7]
    
    low['quality_mark'] = 'low'
    medium['quality_mark'] = 'medium'
    high['quality_mark'] = 'high'
    
    frames = [low, medium, high]
    return pd.concat(frames)

# %%
# Add a column 'quality_mark'for v_blanc 
def add_categ_quality(white_set):
    low = white_set[white_set['quality'] <= 5]
    medium = white_set[(white_set['quality'] == 6) | (white_set['quality'] == 7)]
    high = white_set[white_set['quality'] > 7]
    
    low['quality_mark'] = 'low'
    medium['quality_mark'] = 'medium'
    high['quality_mark'] = 'high'
    
    frames = [low, medium, high]
    return pd.concat(frames)

# %%
def anova(red1_set):
    prepared_data = add_categ_quality(red1_set)
    model1 = smf.ols(formula='alcohol ~ C(quality_mark)', data = prepared_data)
    results1 = model1.fit()
    print(results1.summary())
    
    sub = prepared_data[['alcohol', 'quality_mark']]
    print("\nMeans for Alcahool by quality marks of wine \n")
    print(sub.groupby('quality_mark').mean())
    print('\nStandard deviation for Alcahool by quality marks of wine \n')
    print(sub.groupby('quality_mark').std(), '\n')
    
    # Perform Post hoc test
    mc1 = multi.MultiComparison(sub['alcohol'], sub['quality_mark'])
    res1 = mc1.tukeyhsd()
    print(res1.summary())
    
call_red(anova)
# Out:
# Red Wine
#
#                             OLS Regression Results
# ...
# Dep. Variable:                alcohol   R-squared:                       0.205
# Model:                            OLS   Adj. R-squared:                  0.204
# Method:                 Least Squares   F-statistic:                     205.2
# Date:                Fri, 18 Dec 2020   Prob (F-statistic):           4.78e-80
# Time:                        20:01:03   Log-Likelihood:                -2187.1
# No. Observations:                1599   AIC:                             4380.
# Df Residuals:                    1596   BIC:                             4396.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# <p style="font-family: comic; font-size:1.5em;color:red;">ols interpretation :</p>
# *****************************
# <p style="font-family: comic; font-size:1.1em;color:blue;">R-Squared is 0.205 for your model which is an estimate of the strength of the relationship between the model and the response variable that lies between 0 (worst) and 1 (best).  this is quite low, </p>
#
# <p style="font-family: comic; font-size:1.1em;color:blue;">F-Stat: It is a statistical test that compare the fit of the intercept-only model with your model. the  Prob (F-Statistic) equal is 4.78e-80 close to 0, one can reject the null hypothesis .This implies that overall the regressions is meaningful. </p>
#
# <p style="font-family: comic; font-size:1.1em;color:blue;">Prob(Omnibus): Here, the null hypothesis is that the errors are normally distributed. Prob(Omnibus) is supposed to be close to the 1 in order for it to satisfy the OLS assumption. In this case Prob(Omnibus) is 120.343, which implies that the OLS assumption is not satisfied. Due to this, the coefficients estimated out of it are not Best Linear Unbiased Estimators</p>
#
# <p style="font-family: comic; font-size:1.1em;color:blue;">Durbin-watson: Another assumption of OLS is of homoscedasticity. This implies that the variance of errors is constant. A value between 1 to 2 is preferred. Here, it is ~1.54 implying that the regression results are reliable from the interpretation side of this metric </p>

# %%
def anova(white_set):
    prepared_data = add_categ_quality(white_set)
    model1 = smf.ols(formula='alcohol ~ C(quality_mark)', data = prepared_data)
    results1 = model1.fit()
    print(results1.summary())
    
    sub = prepared_data[['alcohol', 'quality_mark']]
    print("\nMeans for Alcahool by quality marks of wine \n")
    print(sub.groupby('quality_mark').mean())
    print('\nStandard deviation for Alcahool by quality marks of wine \n')
    print(sub.groupby('quality_mark').std(), '\n')
    
    # Perform Post hoc test
    mc1 = multi.MultiComparison(sub['alcohol'], sub['quality_mark'])
    res1 = mc1.tukeyhsd()
    print(res1.summary())
    
call_white(anova)
# Out:
# White Wine
#
#                             OLS Regression Results
# ...
# Dep. Variable:                alcohol   R-squared:                       0.163
# Model:                            OLS   Adj. R-squared:                  0.163
# Method:                 Least Squares   F-statistic:                     478.2
# Date:                Fri, 18 Dec 2020   Prob (F-statistic):          2.06e-190
# Time:                        20:01:03   Log-Likelihood:                -7528.9
# No. Observations:                4898   AIC:                         1.506e+04
# Df Residuals:                    4895   BIC:                         1.508e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# <p style="font-family: comic; font-size:1.5em;color:red;">ols interpretation White Wine :</p>
# *****************************
# <p style="font-family: comic; font-size:1.1em;color:blue;">R-Squared is 0.163 this is quite low, </p>
#
# <p style="font-family: comic; font-size:1.1em;color:blue;">F-Stat: . the  Prob (F-Statistic) equal is 2.06e-190 close to 0, one can reject the null hypothesis .This implies that overall the regressions is meaningful. </p>
#
# <p style="font-family: comic; font-size:1.1em;color:blue;">Prob(Omnibus): Here, the null hypothesis is that the errors are normally distributed. Prob(Omnibus) is supposed to be close to the 1 in order for it to satisfy the OLS assumption. In this case Prob(Omnibus) is  0.000, which implies that the OLS assumption is not satisfied. Due to this, the coefficients estimated out of it are not Best Linear Unbiased Estimators </p>
#
# <p style="font-family: comic; font-size:1.1em;color:blue;">Durbin-watson:  it is ~ 1.430 implying that the regression results are reliable from the interpretation side of this metric </p>

# %%
# Exploring Statistical Interactions
def explore(red1_set):
    low = red1_set[red1_set['quality'] <= 5]
    medium = red1_set[(red1_set['quality'] == 6) | (red1_set['quality'] == 7)]
    high = red1_set[red1_set['quality'] > 7]

    print('association between wine`s density and residual sugar for wines \nof `low` quality')
    print(scipy.stats.pearsonr(low['density'], low["residual sugar"]))
    print('\nof `medium` quality')
    print(scipy.stats.pearsonr(medium['density'], medium["residual sugar"]))
    print('\nof `high` quality')
    print(scipy.stats.pearsonr(high['density'], high["residual sugar"]))

    scat0 = seaborn.regplot(x="density", y="residual sugar", fit_reg=True, data=low)
    plt.xlabel("Density of wine")
    plt.ylabel("Residual sugar in wine, gram")
    plt.title("Association between wine's density and residual sugar for wines of `low` quality")
    plt.show()

    scat0 = seaborn.regplot(x="density", y="residual sugar", fit_reg=True, data=medium)
    plt.xlabel("Density of wine")
    plt.ylabel("Residual sugar in wine, gram")
    plt.title("Association between wine's density and residual sugar for wines of `medium` quality")
    plt.show()

    scat0 = seaborn.regplot(x="density", y="residual sugar", fit_reg=True, data=high)
    plt.xlabel("Density of wine")
    plt.ylabel("Residual sugar in wine, gram")
    plt.title("Association between wine's density and residual sugar for wines of `high` quality\n")
    plt.show()
call_red(explore)
# Out:
# Red Wine
#
# association between wine`s density and residual sugar for wines
# of `low` quality
# (0.4051274774147372, 9.329990304725039e-31)
#
# of `medium` quality
# (0.3301725171944209, 9.754348168743506e-23)
#
# of `high` quality
# (0.5797231322874935, 0.011679205341894067)

# %%
# Exploring Statistical Interactions
def explore(white_set):
    low = white_set[white_set['quality'] <= 5]
    medium = white_set[(white_set['quality'] == 6) | (white_set['quality'] == 7)]
    high = white_set[white_set['quality'] > 7]

    print('association between wine`s density and residual sugar for wines \nof `low` quality')
    print(scipy.stats.pearsonr(low['density'], low["residual sugar"]))
    print('\nof `medium` quality')
    print(scipy.stats.pearsonr(medium['density'], medium["residual sugar"]))
    print('\nof `high` quality')
    print(scipy.stats.pearsonr(high['density'], high["residual sugar"]))

    scat0 = seaborn.regplot(x="density", y="residual sugar", fit_reg=True, data=low)
    plt.xlabel("Density of wine")
    plt.ylabel("Residual sugar in wine, gram")
    plt.title("Association between wine's density and residual sugar for wines of `low` quality")
    plt.show()

    scat0 = seaborn.regplot(x="density", y="residual sugar", fit_reg=True, data=medium)
    plt.xlabel("Density of wine")
    plt.ylabel("Residual sugar in wine, gram")
    plt.title("Association between wine's density and residual sugar for wines of `medium` quality")
    plt.show()

    scat0 = seaborn.regplot(x="density", y="residual sugar", fit_reg=True, data=high)
    plt.xlabel("Density of wine")
    plt.ylabel("Residual sugar in wine, gram")
    plt.title("Association between wine's density and residual sugar for wines of `high` quality\n")
    plt.show()
call_white(explore)
# Out:
# White Wine
#
# association between wine`s density and residual sugar for wines
# of `low` quality
# (0.8796644895829164, 0.0)
#
# of `medium` quality
# (0.8458419941200949, 0.0)
#
# of `high` quality
# (0.8210870208105546, 3.2743806268830606e-45)

# %% [markdown]
#    5. [<div style="font-family: italic; font-size:1.6em;color:#003399;">Machine learning and Prediction Algorithms</span></div>](#paragraph4)
#     <div style="font-family: COMIC; font-size:1.3em;color:#660099;">5-A Quality Prediction Red Wine </span></div>
#     <div style="font-family: COMIC; font-size:1.3em;color:#A4C639;">5-A-a Logistic Regression </span></div>

# %%
#Model Building 

from sklearn.neighbors import KNeighborsClassifier

from sklearn import svm
import time
from sklearn.linear_model import LogisticRegression

from sklearn.model_selection import train_test_split
import pandas as pd
from sklearn.tree import DecisionTreeClassifier, export_graphviz
import sklearn
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
import matplotlib.pyplot as plt
import operator
from sklearn import preprocessing
from sklearn.linear_model import LassoLarsCV
import numpy as np
from sklearn.metrics import mean_squared_error
from sklearn.cluster import KMeans
from scipy.spatial.distance import cdist
from sklearn.decomposition import PCA
import statsmodels.formula.api as smf
import statsmodels.stats.multicomp as multi
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import BernoulliNB

from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
import warnings
warnings.filterwarnings('ignore')

# %%
def log_regression(red1_set):

    from sklearn.model_selection import train_test_split
    w = red1_set


    recode = {3: 0, 4: 0, 5: 0, 6: 1, 7: 1, 8: 1, 9: 1}
    red1_set['quality_c'] = red1_set['quality'].map(recode)

    predictors = red1_set[["sulphates", 'alcohol']]
    targets = red1_set.quality_c

    pred_train, pred_test, tar_train, tar_test = train_test_split(predictors, targets, test_size=.4)
    clf = LogisticRegression()
    clf.fit(pred_train, tar_train)

    predictions = clf.predict(pred_test)
    print('Confusion Matrix:\n',sklearn.metrics.confusion_matrix(tar_test, predictions))
    print('Accuracy:',sklearn.metrics.accuracy_score(tar_test, predictions))
    
    print ('Score:', clf.score(pred_test, tar_test))
    print ('RMSE:', mean_squared_error(predictions, tar_test) ** 0.5)

print('----------------Logistic Regression------------------------')
call_red(log_regression)
# Out:
# ----------------Logistic Regression------------------------
#
# Red Wine
#
# Confusion Matrix:
#  [[212  86]
#  [101 241]]
# Accuracy: 0.7078125
# Score: 0.7078125
# RMSE: 0.5405437077609914

# %% [markdown]
#  <div style="font-family: COMIC; font-size:1.3em;color:green;">5-A-b Random Forest </span></div>

# %%
def decis_tree(red1_set):
    # local variable to identify if the wine_set red 
    w = red1_set
    predictors =  red1_set[["residual sugar", 'alcohol']]
    targets =  red1_set.quality_c

    pred_train, pred_test, tar_train, tar_test = train_test_split(predictors, targets, test_size=.4)
    clf = DecisionTreeClassifier(max_depth = 4)
    clf.fit(pred_train, tar_train)

    predictions = clf.predict(pred_test)
    from graphviz import Source
    from sklearn import tree
    from sklearn.tree import plot_tree
    plt.figure(figsize=(30,20))
    plot_tree(clf)
 
    print('Confusion Matrix:\n',sklearn.metrics.confusion_matrix(tar_test, predictions))
    print('Accuracy:',sklearn.metrics.accuracy_score(tar_test, predictions))
    
    print ('Score:', clf.score(pred_test, tar_test))
    print ('RMSE:', mean_squared_error(predictions, tar_test) ** 0.5)

print('----------------Decision Tree------------------------')



call_red(decis_tree)
# Out:
# ----------------Decision Tree------------------------
#
# Red Wine
#
# Confusion Matrix:
#  [[233  75]
#  [123 209]]
# Accuracy: 0.690625
# Score: 0.690625
# RMSE: 0.5562148865321748

# %% [markdown]
# <div style="font-family: COMIC; font-size:1.3em;color:green;">5-A-c Random Forest </span></div>

# %%
def random_forests(red1_set):
    recode = {3: 0, 4: 0, 5: 0, 6: 1, 7: 1, 8: 1, 9: 1}
    red1_set['quality_c'] = red1_set['quality'].map(recode)
    predictors = red1_set[["density", 'alcohol', 'sulphates', 'pH', 'volatile acidity', 'chlorides', 'fixed acidity',
                           'citric acid', 'residual sugar', 'free sulfur dioxide', 'total sulfur dioxide']]

    targets = red1_set.quality_c

    pred_train, pred_test, tar_train, tar_test = train_test_split(predictors, targets, test_size=.4)
    classifier = RandomForestClassifier(n_estimators=25)
    classifier = classifier.fit(pred_train, tar_train)

    predictions = classifier.predict(pred_test)
    print('Confusion matrix:\n', sklearn.metrics.confusion_matrix(tar_test, predictions))
    print('Accuracy:', sklearn.metrics.accuracy_score(tar_test, predictions))
    model = ExtraTreesClassifier()
    model.fit(pred_train, tar_train)

    print('\nImportance of predictors:')
    dct = dict()
    for c in range(len(predictors.columns)):
        dct[predictors.columns[c]] = model.feature_importances_[c]
    print(sorted(dct.items(), key=operator.itemgetter(1), reverse=True))

    n = 100
    accuracy = [0]*n

    for i in range(n):
        classifier = RandomForestClassifier(n_estimators=i+1)
        classifier = classifier.fit(pred_train, tar_train)
        predictions = classifier.predict(pred_test)
        accuracy[i] = sklearn.metrics.accuracy_score(tar_test, predictions)

    plt.plot(range(1, n+1), accuracy)
    plt.xlabel("Number of trees")
    plt.ylabel("Accuracy of prediction")
    plt.title("Effect of the number of trees on the prediction accuracy")
    plt.show()

    print(accuracy)

print('----------------Random Forests------------------------')
call_red(random_forests)
# Out:
# ----------------Random Forests------------------------
#
# Red Wine
#
# Confusion matrix:
#  [[233  65]
#  [ 59 283]]
# Accuracy: 0.80625
#
# Importance of predictors:
# [('alcohol', 0.1641853404159652), ('sulphates', 0.10971331681654498), ('total sulfur dioxide', 0.10879408504870386), ('volatile acidity', 0.09665524766307346), ('density', 0.086211158855584), ('fixed acidity', 0.07550942066153235), ('free sulfur dioxide', 0.07251078044954473), ('pH', 0.07245942205587085), ('chlorides', 0.07220144323191145), ('citric acid', 0.07181938174321667), ('residual sugar', 0.06994040305805252)]
# ...

# %% [markdown]
# <div style="font-family: COMIC; font-size:1.3em;color:green;">5-A-d KNN </span></div>

# %%
def knn(red1_set):
    
    
    recode = {3: 0, 4: 0, 5: 0, 6: 1, 7: 1, 8: 1, 9: 1}
    red1_set['quality_c'] = red1_set['quality'].map(recode)

    predictors = red1_set[["residual sugar", 'alcohol']]
    targets = red1_set.quality_c

    pred_train, pred_test, tar_train, tar_test = train_test_split(predictors, targets, test_size=.4)
    
    classifier = KNeighborsClassifier()
    classifier = classifier.fit(pred_train, tar_train)

    predictions = classifier.predict(pred_test)
    print('Confusion Matrix:\n',sklearn.metrics.confusion_matrix(tar_test, predictions))
    print('Accuracy:',sklearn.metrics.accuracy_score(tar_test, predictions))
    
    print ('Score:', classifier.score(pred_test, tar_test))
    print ('RMSE:', mean_squared_error(predictions, tar_test) ** 0.5)

    
print('----------------KNN------------------------')
call_red(knn)
# Out:
# ----------------KNN------------------------
#
# Red Wine
#
# Confusion Matrix:
#  [[191 113]
#  [101 235]]
# Accuracy: 0.665625
# Score: 0.665625
# RMSE: 0.5782516753110188

# %% [markdown]
# 5. [<div style="font-family: italic; font-size:1.6em;color:black;">Machine learning and Prediction Algorithms</span></div>](#paragraph4)

# %% [markdown]
# <div style="font-family: COMIC; font-size:1.3em;color:navy;">5-B  Quality Prediction white Wine </span></div>
# <div style="font-family: COMIC; font-size:1.3em;color:green;">5-B-a Logistic Regression </span></div>

# %%
def log_regression(white_set):
    # local variable to identify if the wine_set red or white
    from sklearn.model_selection import train_test_split
    w = white_set

    recode = {3: 0, 4: 0, 5: 0, 6: 1, 7: 1, 8: 1, 9: 1}
    white_set['quality_c'] = white_set['quality'].map(recode)

    predictors = white_set[["sulphates", 'alcohol']]
    targets = white_set.quality_c

    pred_train, pred_test, tar_train, tar_test = train_test_split(predictors, targets, test_size=.4)
    clf = LogisticRegression()
    clf.fit(pred_train, tar_train)

    predictions = clf.predict(pred_test)
    print('Confusion Matrix:\n',sklearn.metrics.confusion_matrix(tar_test, predictions))
    print('Accuracy:',sklearn.metrics.accuracy_score(tar_test, predictions))
    
    print ('Score:', clf.score(pred_test, tar_test))
    print ('RMSE:', mean_squared_error(predictions, tar_test) ** 0.5)

print('__Logistic Regression__')
call_white(log_regression)
# Out:
# __Logistic Regression__
#
# White Wine
#
# Confusion Matrix:
#  [[ 274  402]
#  [ 204 1080]]
# Accuracy: 0.6908163265306122
# Score: 0.6908163265306122
# RMSE: 0.5560428701722446

# %% [markdown]
# <div style="font-family: COMIC; font-size:1.3em;color:green;">5-B-b Decision Tree </span></div>

# %%
def decis_tree(white_set):
    
    w = white_set

    
    predictors =  white_set[["residual sugar", 'alcohol']]
    targets =  white_set.quality_c

    pred_train, pred_test, tar_train, tar_test = train_test_split(predictors, targets, test_size=.4)

    # build model on training data
    clf = DecisionTreeClassifier(max_depth = 4)
    clf.fit(pred_train, tar_train)

    predictions = clf.predict(pred_test)
    from graphviz import Source
    from sklearn import tree
    from sklearn.tree import plot_tree
    plt.figure(figsize=(30,20))
    plot_tree(clf)
     
    print('Confusion Matrix:\n',sklearn.metrics.confusion_matrix(tar_test, predictions))
    print('Accuracy:',sklearn.metrics.accuracy_score(tar_test, predictions))
    
    print ('Score:', clf.score(pred_test, tar_test))
    print ('RMSE:', mean_squared_error(predictions, tar_test) ** 0.5)

print('Decision Tree')



call_white(decis_tree)
# Out:
# Decision Tree
#
# White Wine
#
# Confusion Matrix:
#  [[ 282  379]
#  [ 185 1114]]
# Accuracy: 0.7122448979591837
# Score: 0.7122448979591837
# RMSE: 0.5364280958719596

# %% [markdown]
# <div style="font-family: COMIC; font-size:1.3em;color:green;">5-B-c Random Forest </span></div>

# %%
def random_forests( white_set):
    
    recode = {3: 0, 4: 0, 5: 0, 6: 1, 7: 1, 8: 1, 9: 1}
    white_set['quality_c'] = white_set['quality'].map(recode)

 
    predictors = white_set[["density", 'alcohol', 'sulphates', 'pH', 'volatile acidity', 'chlorides', 'fixed acidity',
                           'citric acid', 'residual sugar', 'free sulfur dioxide', 'total sulfur dioxide']]
    targets = white_set.quality_c
    pred_train, pred_test, tar_train, tar_test = train_test_split(predictors, targets, test_size=.4)
    classifier = RandomForestClassifier(n_estimators=25)
    classifier = classifier.fit(pred_train, tar_train)
    predictions = classifier.predict(pred_test)
    print('Confusion matrix:\n', sklearn.metrics.confusion_matrix(tar_test, predictions))
    print('Accuracy:', sklearn.metrics.accuracy_score(tar_test, predictions))
    model = ExtraTreesClassifier()
    model.fit(pred_train, tar_train)
    print('\nImportance of predictors:')
    dct = dict()
    for c in range(len(predictors.columns)):
        dct[predictors.columns[c]] = model.feature_importances_[c]
    print(sorted(dct.items(), key=operator.itemgetter(1), reverse=True))
    n = 100
    accuracy = [0]*n

    for i in range(n):
        classifier = RandomForestClassifier(n_estimators=i+1)
        classifier = classifier.fit(pred_train, tar_train)
        predictions = classifier.predict(pred_test)
        accuracy[i] = sklearn.metrics.accuracy_score(tar_test, predictions)

    plt.plot(range(1, n+1), accuracy)
    plt.xlabel("Number of trees")
    plt.ylabel("Accuracy of prediction")
    plt.title("Effect of the number of trees on the prediction accuracy")
    plt.show()

    print(accuracy)

print('Random Forests')
call_white(random_forests)
# Out:
# Random Forests
#
# White Wine
#
# Confusion matrix:
#  [[ 432  212]
#  [ 144 1172]]
# Accuracy: 0.8183673469387756
#
# Importance of predictors:
# [('alcohol', 0.16599619779104768), ('volatile acidity', 0.10871750879745362), ('density', 0.09628236945847807), ('citric acid', 0.08675055813669799), ('free sulfur dioxide', 0.08620580848270133), ('total sulfur dioxide', 0.08168657232880407), ('residual sugar', 0.0806743389870641), ('chlorides', 0.07512293979447407), ('pH', 0.07379479603200158), ('fixed acidity', 0.07302733459701427), ('sulphates', 0.07174157559426318)]
# ...

# %% [markdown]
# <div style="font-family: COMIC; font-size:1.3em;color:green;">5-B-d KNN </span></div>

# %%
def knn(white_set):
    
    
    recode = {3: 0, 4: 0, 5: 0, 6: 1, 7: 1, 8: 1, 9: 1}
    white_set['quality_c'] = white_set['quality'].map(recode)

    predictors = white_set[["residual sugar", 'alcohol']]
    targets = white_set.quality_c

    pred_train, pred_test, tar_train, tar_test = train_test_split(predictors, targets, test_size=.4)
    
    classifier = KNeighborsClassifier()
    classifier = classifier.fit(pred_train, tar_train)

    predictions = classifier.predict(pred_test)
    print('Confusion Matrix:\n',sklearn.metrics.confusion_matrix(tar_test, predictions))
    print('Accuracy:',sklearn.metrics.accuracy_score(tar_test, predictions))
    
    print ('Score:', classifier.score(pred_test, tar_test))
    print ('RMSE:', mean_squared_error(predictions, tar_test) ** 0.5)

    
print('----------------KNN------------------------')
call_white(knn)
# Out:
# ----------------KNN------------------------
#
# White Wine
#
# Confusion Matrix:
#  [[ 347  322]
#  [ 256 1035]]
# Accuracy: 0.7051020408163265
# Score: 0.7051020408163265
# RMSE: 0.5430450802499489

# %% [markdown]
# 6. [<div style="font-family: italic; font-size:1.6em;color:black;">Select the best Method</div>](#paragraph4)

# %% [markdown]
#   <div style="font-family: COMIC; font-size:1.3em;color:navy;">6-A Red Wine </span></div>

# %%
print('-----------------Result Logistic Regression-------------------------------')
call_red(log_regression)

print('--------------------Result decision TREE------------------------------------')
call_red(decis_tree)

print('---------------------Result random Forest-------------------------')
call_red(random_forests)

print('-----------------------Result KNN-----------------------------------')
call_red(knn)
# Out:
# -----------------Result Logistic Regression-------------------------------
#
# Red Wine
#
# Confusion Matrix:
#  [[212  93]
#  [ 92 243]]
# Accuracy: 0.7109375
# Score: 0.7109375
# RMSE: 0.5376453291901642
# --------------------Result decision TREE------------------------------------
#
# Red Wine
#
# Confusion Matrix:
#  [[228  78]
#  [124 210]]
# Accuracy: 0.684375
# Score: 0.684375
# RMSE: 0.5618051263561058
# ---------------------Result random Forest-------------------------
#
# Red Wine
#
# Confusion matrix:
#  [[226  72]
#  [ 63 279]]
# Accuracy: 0.7890625
#
# Importance of predictors:
# ...

# %% [markdown]
# For Red wine the best resultgiven by the Random Forest with accuracy 0.80
#
# if we condider the actual position as described in the dataset only we have 10% good quality from total set. we assume this accuracy is very important and can save a lot of money if we plant it .

# %% [markdown]
#   <div style="font-family: COMIC; font-size:1.3em;color:navy;">6-B white Wine </span></div>

# %%
print('-----------------Result Logistic Regression-------------------------------')
call_white(log_regression)

print('--------------------Result decision TREE------------------------------------')
call_white(decis_tree)

print('---------------------Result random Forest-------------------------')
call_white(random_forests)

print('-----------------------Result KNN-----------------------------------')
call_white(knn)
# Out:
# -----------------Result Logistic Regression-------------------------------
#
# White Wine
#
# Confusion Matrix:
#  [[ 301  335]
#  [ 235 1089]]
# Accuracy: 0.7091836734693877
# Score: 0.7091836734693877
# RMSE: 0.539273888233625
# --------------------Result decision TREE------------------------------------
#
# White Wine
#
# Confusion Matrix:
#  [[ 291  353]
#  [ 204 1112]]
# Accuracy: 0.7158163265306122
# Score: 0.7158163265306122
# RMSE: 0.5330888044870083
# ---------------------Result random Forest-------------------------
#
# White Wine
#
# Confusion matrix:
#  [[ 454  215]
#  [ 136 1155]]
# Accuracy: 0.8209183673469388
#
# Importance of predictors:
# ...

# %% [markdown]
# For white wine the best result given by the Random Forest with accuracy 0.82
#
# if we condider the actual position as described in the dataset only we have 10% good quality from total set. we assume this accuracy is very important and can save a lot of money if we plant it .

# %% [markdown]
# 7. [<div style="font-family: italic; font-size:1.6em;color:black;">Conclusion</div>](#paragraph4)

# %% [markdown]
#  <p style="font-family: comic; font-size:1.1em;color:blue;">Technology in the food industry is an essential part of food production and delivery processes. We find food through applications, and manufacturers produce it with  data processing. Tech could significantly improve Quality product, increasing shelf life and food safety. The quality of food is also improving while production costs are lower.</p>
#
#  <p style="font-family: comic; font-size:1.1em;color:blue;">Artificial Intelligence and Machine Learning solutions offer many possibilities to optimize and automate processes, save money, and reduce human error for many industries. AI and ML can benefit agriculture agribusiness ,A as well as in food manufacturing. These two segments have common use cases where AI in the food industry can be applied.</p>
#
#  <p style="font-family: comic; font-size:1.1em;color:blue;">such as our application for this dataset we can reduce costs and quality in every stage from farmer to final consummer</p>
#
#  <p style="font-family: comic; font-size:1.1em;color:blue;">Here, AI in food manufacturing helps to monitor every stage of this process — it makes price and inventory management predictions and tracks the path of goods from where they are grown to the place where consumers receive it,Sorting food: optical sorting solutions,Food-selling ,predict many issues in agriculture in general (our application possibility to prodict the agriculture of graps) .</p>
